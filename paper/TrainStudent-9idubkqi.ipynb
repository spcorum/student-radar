# %%
# Mount Google Drive to access dataset
from google.colab import drive
drive.mount('/content/drive')
import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import wandb
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
print(tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# 2.18.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !nvidia-smi
# Out:
# Thu Jun  5 13:58:25 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0             51W /  400W |       5MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install h5py matplotlib scipy scikit-learn wandb polarTransform pyqtgraph PyQt5
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (3.13.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.11)
# Collecting polarTransform
#   Downloading polarTransform-2.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting pyqtgraph
#   Downloading pyqtgraph-0.13.7-py3-none-any.whl.metadata (1.3 kB)
# Collecting PyQt5
#   Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from h5py) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.2.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.11.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.29.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.13.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from polarTransform) (0.25.2)
# Collecting PyQt5-sip<13,>=12.15 (from PyQt5)
#   Downloading PyQt5_sip-12.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (472 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from PyQt5)
#   Downloading PyQt5_Qt5-5.15.17-py3-none-manylinux2014_x86_64.whl.metadata (536 bytes)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2025.4.26)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->polarTransform) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->polarTransform) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->polarTransform) (2025.5.26)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->polarTransform) (0.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Downloading polarTransform-2.0.0-py3-none-any.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 93.3 MB/s eta 0:00:00
# Downloading pyqtgraph-0.13.7-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 81.4 MB/s eta 0:00:00
# Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 123.6 MB/s eta 0:00:00
# Downloading PyQt5_Qt5-5.15.17-py3-none-manylinux2014_x86_64.whl (61.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 MB 40.2 MB/s eta 0:00:00
# Downloading PyQt5_sip-12.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 25.7 MB/s eta 0:00:00
# Installing collected packages: PyQt5-Qt5, pyqtgraph, PyQt5-sip, PyQt5, polarTransform
# Successfully installed PyQt5-5.15.11 PyQt5-Qt5-5.15.17 PyQt5-sip-12.17.0 polarTransform-2.0.0 pyqtgraph-0.13.7

# %%
print(tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# 2.18.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# for Vimala and Sean
# %cd /content/drive/MyDrive/cs231n/student-radar/paper
# for Susan
# %cd /content/drive/MyDrive/student-radar/paper/
# !pwd
# !ls
# Out:
# /content/drive/MyDrive/cs231n/student-radar/paper
# /content/drive/MyDrive/cs231n/student-radar/paper
# analysis	   DoOriginal.ipynb	 model-gi5l7fcx.h5  summary.svg
# Analysis.ipynb	   DoStudent2.ipynb	 model-rqef7im3.h5  Test3.ipynb
# checkpoints	   DoStudent.ipynb	 model-ryyt9way.h5  Test4.ipynb
# data		   generated_traces.png  README.md	    Test5.ipynb
# DoBoth.ipynb	   Generate.ipynb	 src		    Test.ipynb
# DoOriginal2.ipynb  loss_plot.png	 summary.png	    wandb

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0' # set to 1 for less verbosity (keeps warnings and errors but discards info)

# %%
wandb.login(key="85019a9c3b05de9fa0211a19fd654750ad845f1f")
print(f"Logged in as: {wandb.api.api_key}")
print(f"Entity: {wandb.run.entity if wandb.run else 'No active run'}")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: spcorum (spcorum-aerostar-international) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Logged in as: 85019a9c3b05de9fa0211a19fd654750ad845f1f
# Entity: No active run

# %%
# !python src/models/trainings/train_conditional.py --model_type student --epochs 5000 --batch_size 32 --model_name 9idubkqi
# Out:
# 2025-06-05 13:58:43.208830: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-05 13:58:43.226103: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749131923.247208    1007 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749131923.253528    1007 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-05 13:58:43.274611: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1749131931.273880    1007 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38546 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# I0000 00:00:1749131933.208145    1007 cuda_dnn.cc:529] Loaded cuDNN version 90300
# [INFO] Generator and discriminator successfully built.
# [INFO] GAN model successfully built
# [INFO] Resuming existing run: 9idubkqi
# wandb: Currently logged in as: spcorum (spcorum-aerostar-international) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Resuming run conditional-radar-gan-student
# wandb: ⭐️ View project at https://wandb.ai/spcorum-aerostar-international/student-generative-radar
# wandb: 🚀 View run at https://wandb.ai/spcorum-aerostar-international/student-generative-radar/runs/9idubkqi
# [INFO] Attempting to resume from last checkpoint...
# [INFO] WandB Run URL: https://wandb.ai/spcorum-aerostar-international/student-generative-radar/runs/9idubkqi
# [INFO] Resuming from: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4677.weights.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 50 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# [INFO] GAN successfully built from from: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4677.weights.h5
# /content/drive/MyDrive/cs231n/student-radar/paper/data/preprocessed/EXP_17_M_chirps_scaled_train.npy
#
# Train batches: 137 | Validation batches: 34
#
#
# --------------------- Run: conditional-radar-gan-student ---------------------------
#
#
# [INFO] StudentGAN model successfully built before training.
# 2025-06-05 13:59:36.726502: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# [INFO] Starting training from epoch 4677...
# [INFO] WandB run ID: 9idubkqi
# [INFO] Loaded checkpoint from: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4677.weights.h5
# Epoch 4678/5000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749132016.482349    1126 service.cc:148] XLA service 0x7ac5740057b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749132016.482454    1126 service.cc:156]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2025-06-05 14:00:18.578299: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-06-05 14:01:16.760607: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_reduce_subtract_transpose_fusion_1', 4 bytes spill stores, 16 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_reduce_subtract_transpose_fusion', 8 bytes spill stores, 20 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_15', 4 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_concatenate_fusion_6', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1749132077.339616    1126 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8891 - generator_loss: -0.7521[Log] Similarity metrics at epoch 4677 -> PSD_L2: 0.0000, MMD: 0.7690, KS_p: 0.0285
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4678.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4678.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4678
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4678.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4678.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 113s 89ms/step - discriminator_loss: -0.8892 - generator_loss: -0.7546 - val_discriminator_loss: -0.5210 - val_generator_loss: -1.2536
# Epoch 4679/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9181 - generator_loss: -0.3219[Log] Similarity metrics at epoch 4678 -> PSD_L2: 0.0000, MMD: 0.8037, KS_p: 0.0070
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4679.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4679.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4679
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4679.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4679.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - discriminator_loss: -0.9180 - generator_loss: -0.3258 - val_discriminator_loss: -0.5084 - val_generator_loss: -0.7331
# Epoch 4680/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9384 - generator_loss: -0.1342[Log] Similarity metrics at epoch 4679 -> PSD_L2: 0.0000, MMD: 0.7767, KS_p: 0.0103
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4680.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4680.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4680
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4680.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4680.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 62ms/step - discriminator_loss: -0.9382 - generator_loss: -0.1386 - val_discriminator_loss: -0.5432 - val_generator_loss: -0.5478
# Epoch 4681/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9211 - generator_loss: -0.1747[Log] Similarity metrics at epoch 4680 -> PSD_L2: 0.0000, MMD: 0.8028, KS_p: 0.0401
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4681.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4681.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4681
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4681.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4681.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.9208 - generator_loss: -0.1792 - val_discriminator_loss: -0.4864 - val_generator_loss: -1.1724
# Epoch 4682/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8945 - generator_loss: -0.1935[Log] Similarity metrics at epoch 4681 -> PSD_L2: 0.0000, MMD: 0.8029, KS_p: 0.0224
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4682.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4682.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4682
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4682.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4682.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 60ms/step - discriminator_loss: -0.8946 - generator_loss: -0.1955 - val_discriminator_loss: -0.5042 - val_generator_loss: -0.8525
# Epoch 4683/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8993 - generator_loss: -0.3547[Log] Similarity metrics at epoch 4682 -> PSD_L2: 0.0000, MMD: 0.7125, KS_p: 0.0217
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4683.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4683.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4683
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4683.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4683.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - discriminator_loss: -0.8994 - generator_loss: -0.3607 - val_discriminator_loss: -0.5435 - val_generator_loss: -1.4016
# Epoch 4684/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9218 - generator_loss: -0.8766[Log] Similarity metrics at epoch 4683 -> PSD_L2: 0.0000, MMD: 0.7640, KS_p: 0.0129
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4684.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4684.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4684
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4684.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4684.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.9218 - generator_loss: -0.8842 - val_discriminator_loss: -0.5052 - val_generator_loss: -1.6225
# Epoch 4685/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9050 - generator_loss: -0.9767[Log] Similarity metrics at epoch 4684 -> PSD_L2: 0.0000, MMD: 0.7887, KS_p: 0.0403
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4685.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4685.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4685
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4685.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4685.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - discriminator_loss: -0.9051 - generator_loss: -0.9824 - val_discriminator_loss: -0.4516 - val_generator_loss: -1.9682
# Epoch 4686/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8830 - generator_loss: -1.3666[Log] Similarity metrics at epoch 4685 -> PSD_L2: 0.0000, MMD: 0.8070, KS_p: 0.0185
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4686.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4686.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4686
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4686.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4686.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 65ms/step - discriminator_loss: -0.8830 - generator_loss: -1.3674 - val_discriminator_loss: -0.4596 - val_generator_loss: -1.4547
# Epoch 4687/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8871 - generator_loss: -0.8071[Log] Similarity metrics at epoch 4686 -> PSD_L2: 0.0000, MMD: 0.7822, KS_p: 0.0035
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4687.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4687.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4687
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4687.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4687.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 61ms/step - discriminator_loss: -0.8871 - generator_loss: -0.8109 - val_discriminator_loss: -0.4989 - val_generator_loss: -1.5032
# Epoch 4688/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9109 - generator_loss: -1.0846[Log] Similarity metrics at epoch 4687 -> PSD_L2: 0.0000, MMD: 0.7795, KS_p: 0.0037
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4688.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4688.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4688
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4688.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4688.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - discriminator_loss: -0.9108 - generator_loss: -1.0867 - val_discriminator_loss: -0.5127 - val_generator_loss: -1.4711
# Epoch 4689/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9082 - generator_loss: -1.1736[Log] Similarity metrics at epoch 4688 -> PSD_L2: 0.0000, MMD: 0.7573, KS_p: 0.0287
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4689.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4689.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4689
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4689.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4689.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 50ms/step - discriminator_loss: -0.9083 - generator_loss: -1.1770 - val_discriminator_loss: -0.4384 - val_generator_loss: -1.4471
# Epoch 4690/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8957 - generator_loss: -0.9502[Log] Similarity metrics at epoch 4689 -> PSD_L2: 0.0000, MMD: 0.7349, KS_p: 0.0129
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4690.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4690.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4690
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4690.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4690.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 58ms/step - discriminator_loss: -0.8958 - generator_loss: -0.9531 - val_discriminator_loss: -0.5017 - val_generator_loss: -1.6657
# Epoch 4691/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9050 - generator_loss: -0.7775[Log] Similarity metrics at epoch 4690 -> PSD_L2: 0.0000, MMD: 0.8073, KS_p: 0.0055
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4691.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4691.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4691
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4691.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4691.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.9048 - generator_loss: -0.7830 - val_discriminator_loss: -0.4766 - val_generator_loss: -1.7210
# Epoch 4692/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9051 - generator_loss: -1.0819[Log] Similarity metrics at epoch 4691 -> PSD_L2: 0.0000, MMD: 0.6590, KS_p: 0.0299
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4692.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4692.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4692
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4692.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4692.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - discriminator_loss: -0.9054 - generator_loss: -1.0874 - val_discriminator_loss: -0.4750 - val_generator_loss: -1.8165
# Epoch 4693/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8886 - generator_loss: -1.0118[Log] Similarity metrics at epoch 4692 -> PSD_L2: 0.0000, MMD: 0.7086, KS_p: 0.0406
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4693.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4693.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4693
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4693.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4693.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.8888 - generator_loss: -1.0209 - val_discriminator_loss: -0.4564 - val_generator_loss: -2.2013
# Epoch 4694/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8899 - generator_loss: -1.4141[Log] Similarity metrics at epoch 4693 -> PSD_L2: 0.0000, MMD: 0.7946, KS_p: 0.0085
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4694.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4694.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4694
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4694.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4694.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - discriminator_loss: -0.8899 - generator_loss: -1.4161 - val_discriminator_loss: -0.4849 - val_generator_loss: -1.9741
# Epoch 4695/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9021 - generator_loss: -1.4668[Log] Similarity metrics at epoch 4694 -> PSD_L2: 0.0000, MMD: 0.6935, KS_p: 0.0071
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4695.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4695.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4695
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4695.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4695.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 62ms/step - discriminator_loss: -0.9021 - generator_loss: -1.4698 - val_discriminator_loss: -0.5082 - val_generator_loss: -2.5227
# Epoch 4696/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8949 - generator_loss: -1.7421[Log] Similarity metrics at epoch 4695 -> PSD_L2: 0.0000, MMD: 0.7841, KS_p: 0.0086
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4696.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4696.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4696
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4696.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4696.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - discriminator_loss: -0.8949 - generator_loss: -1.7441 - val_discriminator_loss: -0.4983 - val_generator_loss: -2.6950
# Epoch 4697/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.8987 - generator_loss: -1.6128[Log] Similarity metrics at epoch 4696 -> PSD_L2: 0.0000, MMD: 0.7981, KS_p: 0.0111
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4697.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4697.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4697
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4697.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4697.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 58ms/step - discriminator_loss: -0.8986 - generator_loss: -1.6133 - val_discriminator_loss: -0.4962 - val_generator_loss: -1.7479
# Epoch 4698/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9086 - generator_loss: -1.2278[Log] Similarity metrics at epoch 4697 -> PSD_L2: 0.0000, MMD: 0.7596, KS_p: 0.0165
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4698.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4698.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4698
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4698.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4698.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.9087 - generator_loss: -1.2298 - val_discriminator_loss: -0.5110 - val_generator_loss: -1.6180
# Epoch 4699/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8949 - generator_loss: -1.1864[Log] Similarity metrics at epoch 4698 -> PSD_L2: 0.0000, MMD: 0.7971, KS_p: 0.0335
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4699.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4699.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4699
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4699.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4699.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 64ms/step - discriminator_loss: -0.8950 - generator_loss: -1.1908 - val_discriminator_loss: -0.4607 - val_generator_loss: -1.3767
# Epoch 4700/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8929 - generator_loss: -1.2482[Log] Similarity metrics at epoch 4699 -> PSD_L2: 0.0000, MMD: 0.7735, KS_p: 0.0077
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4700.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4700.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4700
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4700.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4700.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 50ms/step - discriminator_loss: -0.8930 - generator_loss: -1.2525 - val_discriminator_loss: -0.4911 - val_generator_loss: -1.6079
# Epoch 4701/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9137 - generator_loss: -1.5023[Log] Similarity metrics at epoch 4700 -> PSD_L2: 0.0000, MMD: 0.7955, KS_p: 0.0125
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4701.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4701.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4701
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4701.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4701.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.9137 - generator_loss: -1.5045 - val_discriminator_loss: -0.5221 - val_generator_loss: -1.4588
# Epoch 4702/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8557 - generator_loss: -1.5482[Log] Similarity metrics at epoch 4701 -> PSD_L2: 0.0000, MMD: 0.7812, KS_p: 0.0103
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4702.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4702.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4702
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4702.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4702.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 63ms/step - discriminator_loss: -0.8562 - generator_loss: -1.5554 - val_discriminator_loss: -0.4358 - val_generator_loss: -1.7963
# Epoch 4703/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8846 - generator_loss: -1.7524[Log] Similarity metrics at epoch 4702 -> PSD_L2: 0.0000, MMD: 0.7579, KS_p: 0.0019
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4703.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4703.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4703
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4703.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4703.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 58ms/step - discriminator_loss: -0.8845 - generator_loss: -1.7551 - val_discriminator_loss: -0.5421 - val_generator_loss: -2.0041
# Epoch 4704/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9068 - generator_loss: -1.5884[Log] Similarity metrics at epoch 4703 -> PSD_L2: 0.0000, MMD: 0.7858, KS_p: 0.0203
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4704.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4704.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4704
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4704.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4704.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 59ms/step - discriminator_loss: -0.9067 - generator_loss: -1.5925 - val_discriminator_loss: -0.5158 - val_generator_loss: -2.0827
# Epoch 4705/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9092 - generator_loss: -1.8609[Log] Similarity metrics at epoch 4704 -> PSD_L2: 0.0000, MMD: 0.7928, KS_p: 0.0133
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4705.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4705.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4705
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4705.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4705.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.9089 - generator_loss: -1.8641 - val_discriminator_loss: -0.4559 - val_generator_loss: -1.9555
# Epoch 4706/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.8976 - generator_loss: -1.5842[Log] Similarity metrics at epoch 4705 -> PSD_L2: 0.0000, MMD: 0.7896, KS_p: 0.0053
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4706.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4706.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4706
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4706.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4706.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.8976 - generator_loss: -1.5869 - val_discriminator_loss: -0.4642 - val_generator_loss: -2.3052
# Epoch 4707/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8977 - generator_loss: -1.9728[Log] Similarity metrics at epoch 4706 -> PSD_L2: 0.0000, MMD: 0.8067, KS_p: 0.0329
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4707.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4707.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4707
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4707.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4707.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 58ms/step - discriminator_loss: -0.8978 - generator_loss: -1.9782 - val_discriminator_loss: -0.4498 - val_generator_loss: -3.0026
# Epoch 4708/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9083 - generator_loss: -2.3248[Log] Similarity metrics at epoch 4707 -> PSD_L2: 0.0000, MMD: 0.7722, KS_p: 0.0046
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4708.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4708.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4708
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4708.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4708.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - discriminator_loss: -0.9082 - generator_loss: -2.3262 - val_discriminator_loss: -0.4678 - val_generator_loss: -2.5577
# Epoch 4709/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9097 - generator_loss: -1.5880[Log] Similarity metrics at epoch 4708 -> PSD_L2: 0.0000, MMD: 0.8057, KS_p: 0.0137
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4709.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4709.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4709
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4709.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4709.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.9095 - generator_loss: -1.5935 - val_discriminator_loss: -0.4623 - val_generator_loss: -2.1167
# Epoch 4710/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9016 - generator_loss: -1.5319[Log] Similarity metrics at epoch 4709 -> PSD_L2: 0.0000, MMD: 0.7869, KS_p: 0.0322
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4710.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4710.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4710
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4710.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4710.h5
# ...
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4988
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4988.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4988.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 58ms/step - discriminator_loss: -0.8762 - generator_loss: -1.7197 - val_discriminator_loss: -0.4603 - val_generator_loss: -2.2181
# Epoch 4989/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8751 - generator_loss: -2.0873[Log] Similarity metrics at epoch 4988 -> PSD_L2: 0.0000, MMD: 0.7920, KS_p: 0.0087
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4989.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4989.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4989
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4989.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4989.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.8751 - generator_loss: -2.0905 - val_discriminator_loss: -0.4971 - val_generator_loss: -1.8513
# Epoch 4990/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8873 - generator_loss: -1.8203[Log] Similarity metrics at epoch 4989 -> PSD_L2: 0.0000, MMD: 0.7345, KS_p: 0.0091
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4990.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4990.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4990
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4990.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4990.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 58ms/step - discriminator_loss: -0.8873 - generator_loss: -1.8236 - val_discriminator_loss: -0.4510 - val_generator_loss: -1.8868
# Epoch 4991/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8712 - generator_loss: -2.0409[Log] Similarity metrics at epoch 4990 -> PSD_L2: 0.0000, MMD: 0.7366, KS_p: 0.0047
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4991.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4991.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4991
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4991.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4991.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 64ms/step - discriminator_loss: -0.8711 - generator_loss: -2.0475 - val_discriminator_loss: -0.5054 - val_generator_loss: -2.7865
# Epoch 4992/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8839 - generator_loss: -1.9727[Log] Similarity metrics at epoch 4991 -> PSD_L2: 0.0000, MMD: 0.8031, KS_p: 0.0255
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4992.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4992.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4992
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4992.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4992.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.8838 - generator_loss: -1.9780 - val_discriminator_loss: -0.4892 - val_generator_loss: -2.4043
# Epoch 4993/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8818 - generator_loss: -2.2853[Log] Similarity metrics at epoch 4992 -> PSD_L2: 0.0000, MMD: 0.8023, KS_p: 0.0317
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4993.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4993.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4993
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4993.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4993.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 58ms/step - discriminator_loss: -0.8816 - generator_loss: -2.2879 - val_discriminator_loss: -0.5014 - val_generator_loss: -2.4385
# Epoch 4994/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8751 - generator_loss: -2.1419[Log] Similarity metrics at epoch 4993 -> PSD_L2: 0.0000, MMD: 0.7913, KS_p: 0.0084
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4994.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4994.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4994
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4994.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4994.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.8751 - generator_loss: -2.1463 - val_discriminator_loss: -0.4672 - val_generator_loss: -3.1227
# Epoch 4995/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8988 - generator_loss: -2.4053[Log] Similarity metrics at epoch 4994 -> PSD_L2: 0.0000, MMD: 0.7856, KS_p: 0.0035
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4995.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4995.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4995
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4995.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4995.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 58ms/step - discriminator_loss: -0.8987 - generator_loss: -2.4066 - val_discriminator_loss: -0.4659 - val_generator_loss: -2.7203
# Epoch 4996/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8647 - generator_loss: -2.1493[Log] Similarity metrics at epoch 4995 -> PSD_L2: 0.0000, MMD: 0.8012, KS_p: 0.0065
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4996.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4996.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4996
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4996.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4996.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.8648 - generator_loss: -2.1519 - val_discriminator_loss: -0.5251 - val_generator_loss: -2.1392
# Epoch 4997/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8735 - generator_loss: -1.7203[Log] Similarity metrics at epoch 4996 -> PSD_L2: 0.0000, MMD: 0.7125, KS_p: 0.0173
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4997.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4997.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4997
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4997.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4997.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 58ms/step - discriminator_loss: -0.8736 - generator_loss: -1.7260 - val_discriminator_loss: -0.4918 - val_generator_loss: -2.1922
# Epoch 4998/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8268 - generator_loss: -2.0456[Log] Similarity metrics at epoch 4997 -> PSD_L2: 0.0000, MMD: 0.8007, KS_p: 0.0025
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4998.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4998.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4998
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4998.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4998.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - discriminator_loss: -0.8272 - generator_loss: -2.0475 - val_discriminator_loss: -0.5038 - val_generator_loss: -1.9259
# Epoch 4999/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8741 - generator_loss: -1.6978[Log] Similarity metrics at epoch 4998 -> PSD_L2: 0.0000, MMD: 0.7991, KS_p: 0.0021
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-4999.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-4999.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-4999
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-4999.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-4999.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 65ms/step - discriminator_loss: -0.8741 - generator_loss: -1.7002 - val_discriminator_loss: -0.4640 - val_generator_loss: -2.3003
# Epoch 5000/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.8864 - generator_loss: -2.2299[Log] Similarity metrics at epoch 4999 -> PSD_L2: 0.0000, MMD: 0.7898, KS_p: 0.0036
# [Saved] Model weights saved to: ./checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-5000.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-9idubkqi/backup-epoch-5000.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_135856-9idubkqi/files/model-9idubkqi.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-9idubkqi/generator-epoch-5000
# [Cleanup] Deleted old backup: ./checkpoints/student/model-9idubkqi/backup-epoch-5000.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-9idubkqi/generator-epoch-5000.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 58ms/step - discriminator_loss: -0.8864 - generator_loss: -2.2320 - val_discriminator_loss: -0.4606 - val_generator_loss: -3.0383
#
# [INFO] Total training time: 4573.06 seconds
