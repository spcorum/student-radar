# %%
# Mount Google Drive to access dataset
from google.colab import drive
drive.mount('/content/drive')
import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import wandb
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
print(tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# 2.18.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !nvidia-smi
# Out:
# Thu Jun  5 18:45:39 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             45W /  400W |       5MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install h5py matplotlib scipy scikit-learn wandb polarTransform pyqtgraph PyQt5
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (3.13.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.11)
# Collecting polarTransform
#   Downloading polarTransform-2.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting pyqtgraph
#   Downloading pyqtgraph-0.13.7-py3-none-any.whl.metadata (1.3 kB)
# Collecting PyQt5
#   Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from h5py) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.2.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.11.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.29.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.13.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from polarTransform) (0.25.2)
# Collecting PyQt5-sip<13,>=12.15 (from PyQt5)
#   Downloading PyQt5_sip-12.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (472 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from PyQt5)
#   Downloading PyQt5_Qt5-5.15.17-py3-none-manylinux2014_x86_64.whl.metadata (536 bytes)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2025.4.26)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->polarTransform) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->polarTransform) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->polarTransform) (2025.5.26)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->polarTransform) (0.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Downloading polarTransform-2.0.0-py3-none-any.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 112.0 MB/s eta 0:00:00
# Downloading pyqtgraph-0.13.7-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 85.6 MB/s eta 0:00:00
# Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 115.2 MB/s eta 0:00:00
# Downloading PyQt5_Qt5-5.15.17-py3-none-manylinux2014_x86_64.whl (61.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 MB 41.5 MB/s eta 0:00:00
# Downloading PyQt5_sip-12.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 24.7 MB/s eta 0:00:00
# Installing collected packages: PyQt5-Qt5, pyqtgraph, PyQt5-sip, PyQt5, polarTransform
# Successfully installed PyQt5-5.15.11 PyQt5-Qt5-5.15.17 PyQt5-sip-12.17.0 polarTransform-2.0.0 pyqtgraph-0.13.7

# %%
print(tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# 2.18.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# for Vimala and Sean
# %cd /content/drive/MyDrive/cs231n/student-radar/paper
# for Susan
# %cd /content/drive/MyDrive/student-radar/paper/
# !ls
# Out:
# /content/drive/MyDrive/cs231n/student-radar/paper
# analysis	DoBoth.ipynb	   DoStudent.ipynb	 README.md    wandb
# Analysis.ipynb	DoOriginal2.ipynb  generated_traces.png  src
# checkpoints	DoOriginal.ipynb   Generate.ipynb	 summary.png
# data		DoStudent2.ipynb   loss_plot.png	 summary.svg

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0' # set to 1 for less verbosity (keeps warnings and errors but discards info)

# %%
wandb.login(key="85019a9c3b05de9fa0211a19fd654750ad845f1f")
print(f"Logged in as: {wandb.api.api_key}")
print(f"Entity: {wandb.run.entity if wandb.run else 'No active run'}")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: spcorum (spcorum-aerostar-international) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Logged in as: 85019a9c3b05de9fa0211a19fd654750ad845f1f
# Entity: No active run

# %%
# !python src/models/trainings/train_conditional.py --model_type student --epochs 5000 --batch_size 32 --model_name h1k2x95j
# Out:
# Streaming output truncated to the last 5000 lines.
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4501.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4501.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4501
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4501.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4501.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9893 - generator_loss: 3.1176 - val_discriminator_loss: -0.5634 - val_generator_loss: 3.0787
# Epoch 4502/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9905 - generator_loss: 3.1286[Log] Similarity metrics at epoch 4501 -> PSD_L2: 0.0000, MMD: 0.7213, KS_p: 0.0109
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4502.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4502.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4502
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4502.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4502.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9903 - generator_loss: 3.1240 - val_discriminator_loss: -0.6153 - val_generator_loss: 3.2112
# Epoch 4503/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9867 - generator_loss: 2.9639[Log] Similarity metrics at epoch 4502 -> PSD_L2: 0.0000, MMD: 0.7887, KS_p: 0.0306
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4503.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4503.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4503
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4503.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4503.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9865 - generator_loss: 2.9617 - val_discriminator_loss: -0.5740 - val_generator_loss: 3.3810
# Epoch 4504/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9839 - generator_loss: 3.1046[Log] Similarity metrics at epoch 4503 -> PSD_L2: 0.0000, MMD: 0.6823, KS_p: 0.0306
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4504.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4504.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4504
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4504.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4504.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9837 - generator_loss: 3.1029 - val_discriminator_loss: -0.6039 - val_generator_loss: 3.1484
# Epoch 4505/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9574 - generator_loss: 3.2691[Log] Similarity metrics at epoch 4504 -> PSD_L2: 0.0000, MMD: 0.7784, KS_p: 0.0044
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4505.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4505.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4505
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4505.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4505.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9573 - generator_loss: 3.2637 - val_discriminator_loss: -0.5884 - val_generator_loss: 2.8948
# Epoch 4506/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9669 - generator_loss: 2.9773[Log] Similarity metrics at epoch 4505 -> PSD_L2: 0.0000, MMD: 0.7872, KS_p: 0.0061
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4506.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4506.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4506
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4506.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4506.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9669 - generator_loss: 2.9755 - val_discriminator_loss: -0.5674 - val_generator_loss: 3.1914
# Epoch 4507/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9451 - generator_loss: 3.2575[Log] Similarity metrics at epoch 4506 -> PSD_L2: 0.0000, MMD: 0.7924, KS_p: 0.0017
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4507.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4507.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4507
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4507.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4507.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 60ms/step - discriminator_loss: -0.9453 - generator_loss: 3.2512 - val_discriminator_loss: -0.6215 - val_generator_loss: 3.0754
# Epoch 4508/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9837 - generator_loss: 3.2385[Log] Similarity metrics at epoch 4507 -> PSD_L2: 0.0000, MMD: 0.7902, KS_p: 0.0170
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4508.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4508.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4508
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4508.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4508.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 55ms/step - discriminator_loss: -0.9836 - generator_loss: 3.2372 - val_discriminator_loss: -0.5960 - val_generator_loss: 3.9213
# Epoch 4509/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9726 - generator_loss: 3.5648[Log] Similarity metrics at epoch 4508 -> PSD_L2: 0.0000, MMD: 0.7605, KS_p: 0.0062
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4509.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4509.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4509
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4509.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4509.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - discriminator_loss: -0.9725 - generator_loss: 3.5598 - val_discriminator_loss: -0.5382 - val_generator_loss: 3.4129
# Epoch 4510/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9868 - generator_loss: 3.5057[Log] Similarity metrics at epoch 4509 -> PSD_L2: 0.0000, MMD: 0.7880, KS_p: 0.0022
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4510.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4510.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4510
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4510.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4510.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9865 - generator_loss: 3.5002 - val_discriminator_loss: -0.5881 - val_generator_loss: 3.7220
# Epoch 4511/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9734 - generator_loss: 3.4592[Log] Similarity metrics at epoch 4510 -> PSD_L2: 0.0000, MMD: 0.7882, KS_p: 0.0188
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4511.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4511.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4511
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4511.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4511.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - discriminator_loss: -0.9733 - generator_loss: 3.4541 - val_discriminator_loss: -0.6447 - val_generator_loss: 3.2160
# Epoch 4512/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9671 - generator_loss: 3.3527[Log] Similarity metrics at epoch 4511 -> PSD_L2: 0.0000, MMD: 0.7891, KS_p: 0.0211
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4512.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4512.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4512
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4512.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4512.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - discriminator_loss: -0.9670 - generator_loss: 3.3495 - val_discriminator_loss: -0.6502 - val_generator_loss: 3.9262
# Epoch 4513/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9425 - generator_loss: 3.5529[Log] Similarity metrics at epoch 4512 -> PSD_L2: 0.0000, MMD: 0.7866, KS_p: 0.0063
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4513.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4513.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4513
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4513.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4513.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9427 - generator_loss: 3.5476 - val_discriminator_loss: -0.6227 - val_generator_loss: 3.7107
# Epoch 4514/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9936 - generator_loss: 3.6034[Log] Similarity metrics at epoch 4513 -> PSD_L2: 0.0000, MMD: 0.7879, KS_p: 0.0431
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4514.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4514.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4514
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4514.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4514.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 59ms/step - discriminator_loss: -0.9935 - generator_loss: 3.6016 - val_discriminator_loss: -0.5649 - val_generator_loss: 4.1487
# Epoch 4515/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9923 - generator_loss: 3.7693[Log] Similarity metrics at epoch 4514 -> PSD_L2: 0.0000, MMD: 0.7844, KS_p: 0.0255
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4515.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4515.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4515
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4515.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4515.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9920 - generator_loss: 3.7613 - val_discriminator_loss: -0.6268 - val_generator_loss: 3.7226
# Epoch 4516/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9740 - generator_loss: 3.4233[Log] Similarity metrics at epoch 4515 -> PSD_L2: 0.0000, MMD: 0.7687, KS_p: 0.0207
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4516.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4516.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4516
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4516.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4516.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - discriminator_loss: -0.9741 - generator_loss: 3.4189 - val_discriminator_loss: -0.6241 - val_generator_loss: 3.2903
# Epoch 4517/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9965 - generator_loss: 3.1731[Log] Similarity metrics at epoch 4516 -> PSD_L2: 0.0000, MMD: 0.7737, KS_p: 0.0055
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4517.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4517.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4517
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4517.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4517.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9961 - generator_loss: 3.1702 - val_discriminator_loss: -0.5734 - val_generator_loss: 4.0607
# Epoch 4518/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9765 - generator_loss: 3.5251[Log] Similarity metrics at epoch 4517 -> PSD_L2: 0.0000, MMD: 0.7757, KS_p: 0.0395
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4518.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4518.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4518
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4518.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4518.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9764 - generator_loss: 3.5227 - val_discriminator_loss: -0.6299 - val_generator_loss: 3.7913
# Epoch 4519/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9762 - generator_loss: 3.3467[Log] Similarity metrics at epoch 4518 -> PSD_L2: 0.0000, MMD: 0.7627, KS_p: 0.0083
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4519.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4519.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4519
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4519.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4519.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - discriminator_loss: -0.9762 - generator_loss: 3.3442 - val_discriminator_loss: -0.6081 - val_generator_loss: 3.0900
# Epoch 4520/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9575 - generator_loss: 3.2907[Log] Similarity metrics at epoch 4519 -> PSD_L2: 0.0000, MMD: 0.7914, KS_p: 0.0368
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4520.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4520.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4520
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4520.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4520.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9575 - generator_loss: 3.2888 - val_discriminator_loss: -0.5853 - val_generator_loss: 3.3306
# Epoch 4521/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9808 - generator_loss: 3.3032[Log] Similarity metrics at epoch 4520 -> PSD_L2: 0.0000, MMD: 0.7763, KS_p: 0.0110
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4521.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4521.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4521
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4521.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4521.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - discriminator_loss: -0.9804 - generator_loss: 3.2981 - val_discriminator_loss: -0.6461 - val_generator_loss: 3.8221
# Epoch 4522/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9849 - generator_loss: 3.3631[Log] Similarity metrics at epoch 4521 -> PSD_L2: 0.0000, MMD: 0.7379, KS_p: 0.0140
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4522.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4522.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4522
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4522.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4522.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 61ms/step - discriminator_loss: -0.9848 - generator_loss: 3.3550 - val_discriminator_loss: -0.5757 - val_generator_loss: 3.4630
# Epoch 4523/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9747 - generator_loss: 3.3137[Log] Similarity metrics at epoch 4522 -> PSD_L2: 0.0000, MMD: 0.7646, KS_p: 0.0146
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4523.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4523.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4523
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4523.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4523.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 54ms/step - discriminator_loss: -0.9748 - generator_loss: 3.3126 - val_discriminator_loss: -0.5160 - val_generator_loss: 3.8367
# Epoch 4524/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9645 - generator_loss: 3.5414[Log] Similarity metrics at epoch 4523 -> PSD_L2: 0.0000, MMD: 0.7908, KS_p: 0.0257
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4524.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4524.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4524
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4524.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4524.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 55ms/step - discriminator_loss: -0.9644 - generator_loss: 3.5396 - val_discriminator_loss: -0.6056 - val_generator_loss: 4.0242
# Epoch 4525/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9945 - generator_loss: 3.6616[Log] Similarity metrics at epoch 4524 -> PSD_L2: 0.0000, MMD: 0.7695, KS_p: 0.0119
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4525.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4525.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4525
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4525.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4525.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - discriminator_loss: -0.9943 - generator_loss: 3.6570 - val_discriminator_loss: -0.5708 - val_generator_loss: 3.8058
# Epoch 4526/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9663 - generator_loss: 3.5038[Log] Similarity metrics at epoch 4525 -> PSD_L2: 0.0000, MMD: 0.7534, KS_p: 0.0104
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4526.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4526.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4526
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4526.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4526.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9664 - generator_loss: 3.5015 - val_discriminator_loss: -0.6611 - val_generator_loss: 4.2332
# Epoch 4527/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -1.0054 - generator_loss: 3.6958[Log] Similarity metrics at epoch 4526 -> PSD_L2: 0.0000, MMD: 0.7916, KS_p: 0.0210
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4527.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4527.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4527
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4527.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4527.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -1.0047 - generator_loss: 3.6877 - val_discriminator_loss: -0.6124 - val_generator_loss: 3.9149
# Epoch 4528/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9751 - generator_loss: 3.4884[Log] Similarity metrics at epoch 4527 -> PSD_L2: 0.0000, MMD: 0.7734, KS_p: 0.0073
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4528.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4528.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4528
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4528.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4528.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - discriminator_loss: -0.9750 - generator_loss: 3.4835 - val_discriminator_loss: -0.5616 - val_generator_loss: 3.6249
# Epoch 4529/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9549 - generator_loss: 3.7984[Log] Similarity metrics at epoch 4528 -> PSD_L2: 0.0000, MMD: 0.7911, KS_p: 0.0304
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4529.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4529.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4529
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4529.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4529.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 64ms/step - discriminator_loss: -0.9549 - generator_loss: 3.7956 - val_discriminator_loss: -0.6104 - val_generator_loss: 3.9134
# Epoch 4530/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9907 - generator_loss: 3.4842[Log] Similarity metrics at epoch 4529 -> PSD_L2: 0.0000, MMD: 0.7183, KS_p: 0.0222
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4530.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4530.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4530
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4530.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4530.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 70ms/step - discriminator_loss: -0.9906 - generator_loss: 3.4795 - val_discriminator_loss: -0.5664 - val_generator_loss: 3.7994
# Epoch 4531/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -1.0023 - generator_loss: 3.4574[Log] Similarity metrics at epoch 4530 -> PSD_L2: 0.0000, MMD: 0.7753, KS_p: 0.0015
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4531.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4531.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4531
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4531.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4531.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - discriminator_loss: -1.0020 - generator_loss: 3.4542 - val_discriminator_loss: -0.6230 - val_generator_loss: 4.6096
# Epoch 4532/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9823 - generator_loss: 3.7614[Log] Similarity metrics at epoch 4531 -> PSD_L2: 0.0000, MMD: 0.7749, KS_p: 0.0258
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4532.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4532.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4532
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4532.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4532.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9823 - generator_loss: 3.7566 - val_discriminator_loss: -0.6188 - val_generator_loss: 3.7426
# Epoch 4533/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9845 - generator_loss: 3.6621[Log] Similarity metrics at epoch 4532 -> PSD_L2: 0.0000, MMD: 0.7274, KS_p: 0.0045
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4533.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4533.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4533
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4533.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4533.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - discriminator_loss: -0.9844 - generator_loss: 3.6591 - val_discriminator_loss: -0.5663 - val_generator_loss: 4.4112
# Epoch 4534/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9682 - generator_loss: 3.9294[Log] Similarity metrics at epoch 4533 -> PSD_L2: 0.0000, MMD: 0.7595, KS_p: 0.0010
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4534.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4534.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4534
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4534.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4534.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 53ms/step - discriminator_loss: -0.9683 - generator_loss: 3.9278 - val_discriminator_loss: -0.5278 - val_generator_loss: 3.7565
# Epoch 4535/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9719 - generator_loss: 4.0635[Log] Similarity metrics at epoch 4534 -> PSD_L2: 0.0000, MMD: 0.7414, KS_p: 0.0190
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4535.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4535.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4535
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4535.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4535.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - discriminator_loss: -0.9718 - generator_loss: 4.0567 - val_discriminator_loss: -0.6080 - val_generator_loss: 3.8160
# Epoch 4536/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9836 - generator_loss: 3.9804[Log] Similarity metrics at epoch 4535 -> PSD_L2: 0.0000, MMD: 0.7629, KS_p: 0.0327
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4536.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4536.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4536
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4536.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4536.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - discriminator_loss: -0.9834 - generator_loss: 3.9783 - val_discriminator_loss: -0.6100 - val_generator_loss: 4.4682
# Epoch 4537/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9796 - generator_loss: 3.8359[Log] Similarity metrics at epoch 4536 -> PSD_L2: 0.0000, MMD: 0.7958, KS_p: 0.0083
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4537.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4537.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4537
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4537.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4537.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 59ms/step - discriminator_loss: -0.9796 - generator_loss: 3.8310 - val_discriminator_loss: -0.5918 - val_generator_loss: 4.3286
# Epoch 4538/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9894 - generator_loss: 3.7670[Log] Similarity metrics at epoch 4537 -> PSD_L2: 0.0000, MMD: 0.7931, KS_p: 0.0023
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4538.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4538.weights.h5
# ...
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4988
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4988.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4988.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - discriminator_loss: -0.9454 - generator_loss: 4.7471 - val_discriminator_loss: -0.6015 - val_generator_loss: 4.7004
# Epoch 4989/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9632 - generator_loss: 4.9121[Log] Similarity metrics at epoch 4988 -> PSD_L2: 0.0000, MMD: 0.7405, KS_p: 0.0186
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4989.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4989.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4989
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4989.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4989.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - discriminator_loss: -0.9631 - generator_loss: 4.9098 - val_discriminator_loss: -0.6054 - val_generator_loss: 4.7597
# Epoch 4990/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9424 - generator_loss: 4.6912[Log] Similarity metrics at epoch 4989 -> PSD_L2: 0.0000, MMD: 0.7943, KS_p: 0.0128
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4990.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4990.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4990
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4990.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4990.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9423 - generator_loss: 4.6899 - val_discriminator_loss: -0.5740 - val_generator_loss: 5.2652
# Epoch 4991/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - discriminator_loss: -0.9271 - generator_loss: 5.0572[Log] Similarity metrics at epoch 4990 -> PSD_L2: 0.0000, MMD: 0.7360, KS_p: 0.0012
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4991.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4991.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4991
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4991.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4991.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9272 - generator_loss: 5.0533 - val_discriminator_loss: -0.5320 - val_generator_loss: 5.6549
# Epoch 4992/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9316 - generator_loss: 5.4734[Log] Similarity metrics at epoch 4991 -> PSD_L2: 0.0000, MMD: 0.7661, KS_p: 0.0007
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4992.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4992.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4992
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4992.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4992.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 59ms/step - discriminator_loss: -0.9316 - generator_loss: 5.4709 - val_discriminator_loss: -0.5921 - val_generator_loss: 5.5988
# Epoch 4993/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9768 - generator_loss: 5.1650[Log] Similarity metrics at epoch 4992 -> PSD_L2: 0.0000, MMD: 0.7695, KS_p: 0.0039
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4993.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4993.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4993
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4993.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4993.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 55ms/step - discriminator_loss: -0.9764 - generator_loss: 5.1611 - val_discriminator_loss: -0.5860 - val_generator_loss: 5.1387
# Epoch 4994/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9192 - generator_loss: 5.1127[Log] Similarity metrics at epoch 4993 -> PSD_L2: 0.0000, MMD: 0.7892, KS_p: 0.0022
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4994.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4994.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4994
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4994.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4994.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - discriminator_loss: -0.9193 - generator_loss: 5.1080 - val_discriminator_loss: -0.5643 - val_generator_loss: 5.2695
# Epoch 4995/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9428 - generator_loss: 5.2105[Log] Similarity metrics at epoch 4994 -> PSD_L2: 0.0000, MMD: 0.7932, KS_p: 0.0017
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4995.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4995.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4995
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4995.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4995.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9428 - generator_loss: 5.2087 - val_discriminator_loss: -0.5481 - val_generator_loss: 5.0470
# Epoch 4996/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9431 - generator_loss: 5.2361[Log] Similarity metrics at epoch 4995 -> PSD_L2: 0.0000, MMD: 0.7973, KS_p: 0.0038
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4996.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4996.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4996
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4996.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4996.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9431 - generator_loss: 5.2335 - val_discriminator_loss: -0.5310 - val_generator_loss: 4.8187
# Epoch 4997/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9349 - generator_loss: 5.1512[Log] Similarity metrics at epoch 4996 -> PSD_L2: 0.0000, MMD: 0.7597, KS_p: 0.0016
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4997.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4997.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4997
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4997.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4997.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - discriminator_loss: -0.9351 - generator_loss: 5.1448 - val_discriminator_loss: -0.5636 - val_generator_loss: 4.7455
# Epoch 4998/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9368 - generator_loss: 5.0424[Log] Similarity metrics at epoch 4997 -> PSD_L2: 0.0000, MMD: 0.7938, KS_p: 0.0031
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4998.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4998.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4998
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4998.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4998.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - discriminator_loss: -0.9369 - generator_loss: 5.0372 - val_discriminator_loss: -0.5257 - val_generator_loss: 5.3814
# Epoch 4999/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9240 - generator_loss: 4.9213[Log] Similarity metrics at epoch 4998 -> PSD_L2: 0.0000, MMD: 0.7968, KS_p: 0.0259
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-4999.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-4999.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-4999
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-4999.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-4999.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - discriminator_loss: -0.9241 - generator_loss: 4.9149 - val_discriminator_loss: -0.5797 - val_generator_loss: 5.3588
# Epoch 5000/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - discriminator_loss: -0.9098 - generator_loss: 4.7842[Log] Similarity metrics at epoch 4999 -> PSD_L2: 0.0000, MMD: 0.7820, KS_p: 0.0247
# [Saved] Model weights saved to: ./checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-5000.weights.h5
# [Backup] Model weights saved to: ./checkpoints/student/model-h1k2x95j/backup-epoch-5000.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_184601-h1k2x95j/files/model-h1k2x95j.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/student/model-h1k2x95j/generator-epoch-5000
# [Cleanup] Deleted old backup: ./checkpoints/student/model-h1k2x95j/backup-epoch-5000.weights.h5
# [Cleanup] Deleted old generator: ./checkpoints/student/model-h1k2x95j/generator-epoch-5000.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 14s 59ms/step - discriminator_loss: -0.9102 - generator_loss: 4.7770 - val_discriminator_loss: -0.5633 - val_generator_loss: 5.1516
#
# [INFO] Total training time: 9562.95 seconds
