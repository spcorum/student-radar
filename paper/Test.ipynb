# %%
# Mount Google Drive to access dataset
from google.colab import drive
drive.mount('/content/drive')
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install torch torchvision numpy h5py matplotlib scipy scikit-learn wandb

# %%
# !find /content/drive/MyDrive/student-radar -name "train_conditional.py"
# Out:
# /content/drive/MyDrive/student-radar/paper/src/models/trainings/train_conditional.py

# %%
# %cd /content/drive/MyDrive/student-radar/paper/src
# Out:
# /content/drive/MyDrive/student-radar/paper/src

# %%
import os
cwd= os.getcwd()
print(cwd)
# Out:
# /content/drive/MyDrive/student-radar/paper/src

# %%
os.chdir('/content/drive/MyDrive/student-radar/paper/src')

# %%
# !python models/trainings/train_conditional.py
# Out:
# 2025-05-25 00:13:34.622023: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748132014.641633    7909 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748132014.647653    7909 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-25 00:13:41.492193: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# No GPU device found. Using CPU.
# ...

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
import tensorflow as tf
print("Available devices:")
print(tf.config.list_physical_devices())
print("\nIs GPU being used?")
print(tf.config.list_physical_devices('GPU'))
# Out:
# Available devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
#
# Is GPU being used?
# []

# %%
# !nvidia-smi
# Out:
# Sun May 25 00:06:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1180271646981949186
# xla_global_id: -1
# ]

# %%
import tensorflow as tf
print("Is GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# Is GPU available: []

# %%
# !nvidia-smi
# Out:
# Sun May 25 00:06:33 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
