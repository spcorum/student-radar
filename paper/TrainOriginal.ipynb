# %%
# Mount Google Drive to access dataset
from google.colab import drive
drive.mount('/content/drive')
import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
print(tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# 2.18.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !nvidia-smi
# Out:
# Thu Jun  5 07:24:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             44W /  400W |       5MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install h5py matplotlib scipy scikit-learn wandb polarTransform pyqtgraph PyQt5
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (3.13.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.11)
# Collecting polarTransform
#   Downloading polarTransform-2.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting pyqtgraph
#   Downloading pyqtgraph-0.13.7-py3-none-any.whl.metadata (1.3 kB)
# Collecting PyQt5
#   Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from h5py) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.2.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.11.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.29.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.13.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from polarTransform) (0.25.2)
# Collecting PyQt5-sip<13,>=12.15 (from PyQt5)
#   Downloading PyQt5_sip-12.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (472 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from PyQt5)
#   Downloading PyQt5_Qt5-5.15.17-py3-none-manylinux2014_x86_64.whl.metadata (536 bytes)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2025.4.26)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->polarTransform) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->polarTransform) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->polarTransform) (2025.5.26)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->polarTransform) (0.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Downloading polarTransform-2.0.0-py3-none-any.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 120.4 MB/s eta 0:00:00
# Downloading pyqtgraph-0.13.7-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 93.1 MB/s eta 0:00:00
# Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 141.6 MB/s eta 0:00:00
# Downloading PyQt5_Qt5-5.15.17-py3-none-manylinux2014_x86_64.whl (61.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 MB 41.9 MB/s eta 0:00:00
# Downloading PyQt5_sip-12.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 24.6 MB/s eta 0:00:00
# Installing collected packages: PyQt5-Qt5, pyqtgraph, PyQt5-sip, PyQt5, polarTransform
# Successfully installed PyQt5-5.15.11 PyQt5-Qt5-5.15.17 PyQt5-sip-12.17.0 polarTransform-2.0.0 pyqtgraph-0.13.7

# %%
import tensorflow as tf
print(tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# 2.18.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# for Vimala and Sean
# %cd /content/drive/MyDrive/cs231n/student-radar/paper
# for Susan
# %cd /content/drive/MyDrive/student-radar/paper/
# !pwd
# !ls
# Out:
# /content/drive/MyDrive/cs231n/student-radar/paper
# /content/drive/MyDrive/cs231n/student-radar/paper
# analysis	  DoStudent2.ipynb	model-rqef7im3.h5  Test3.ipynb
# Analysis.ipynb	  DoStudent.ipynb	model-ryyt9way.h5  Test4.ipynb
# checkpoints	  generated_traces.png	README.md	   Test5.ipynb
# data		  Generate.ipynb	src		   Test.ipynb
# DoBoth.ipynb	  loss_plot.png		summary.png	   wandb
# DoOriginal.ipynb  model-gi5l7fcx.h5	summary.svg

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0' # set to 1 for less verbosity (keeps warnings and errors but discards info)

# %%
import wandb
wandb.login(key="85019a9c3b05de9fa0211a19fd654750ad845f1f")
print(f"Logged in as: {wandb.api.api_key}")
print(f"Entity: {wandb.run.entity if wandb.run else 'No active run'}")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Logged in as: 85019a9c3b05de9fa0211a19fd654750ad845f1f
# Entity: No active run

# %%
# !python src/models/trainings/train_conditional.py --model_type original --epochs 5000 --batch_size 32
# Out:
# 2025-06-05 07:42:50.129807: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-05 07:42:50.146953: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749109370.167463   12176 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749109370.173785   12176 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-05 07:42:50.194301: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1749109375.034116   12176 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38546 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1749109375.984110   12176 cuda_dnn.cc:529] Loaded cuDNN version 90300
# [INFO] Generator and discriminator successfully built.
# [INFO] GAN model successfully built
# [INFO] Resuming existing run: ltuwf57w
# wandb: Currently logged in as: spcorum (spcorum-aerostar-international) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Resuming run conditional-radar-gan-original
# wandb: ⭐️ View project at https://wandb.ai/spcorum-aerostar-international/student-generative-radar
# wandb: 🚀 View run at https://wandb.ai/spcorum-aerostar-international/student-generative-radar/runs/ltuwf57w
# [INFO] Attempting to resume from last checkpoint...
# [INFO] Checkpoint search pattern: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-*.weights.h5
# [INFO] WandB Run URL: https://wandb.ai/spcorum-aerostar-international/student-generative-radar/runs/ltuwf57w
# [INFO] Resuming from: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4640.weights.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# [INFO] GAN successfully built from from: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4640.weights.h5
# /content/drive/MyDrive/cs231n/student-radar/paper/data/preprocessed/EXP_17_M_chirps_scaled_train.npy
#
# Train batches: 137 | Validation batches: 34
#
#
# --------------------- Run: conditional-radar-gan-original ---------------------------
#
#
# 2025-06-05 07:43:33.639310: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# [INFO] CWGANGP or CWGANGPOriginal model successfully built before training.
# [INFO] Resuming training from epoch 4640...
# [INFO] WandB run ID: ltuwf57w
# [INFO] Loaded checkpoint from: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4640.weights.h5
# Epoch 4641/5000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749109423.238503   12272 service.cc:148] XLA service 0x7a3300015c10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749109423.238551   12272 service.cc:156]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2025-06-05 07:43:43.635756: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1749109436.512430   12272 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -66.8888 - generator_loss: 57.8720[Log] Similarity metrics at epoch 4640 -> PSD_L2: 0.0000, MMD: 0.6736, KS_p: 0.0000
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4641.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4641.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4641
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4640.weights.h5
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4641.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 31s 57ms/step - discriminator_loss: -66.4697 - generator_loss: 57.6334 - val_discriminator_loss: -31.3412 - val_generator_loss: 20.9477
# Epoch 4642/5000
# 129/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -19.2505 - generator_loss: 1.3197wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4640 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -19.0385 - generator_loss: 0.9392[Log] Similarity metrics at epoch 4641 -> PSD_L2: 0.0000, MMD: 0.6736, KS_p: 0.0003
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4642.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4642.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4642
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4642.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - discriminator_loss: -19.0127 - generator_loss: 0.8947 - val_discriminator_loss: -11.6250 - val_generator_loss: -5.0336
# Epoch 4643/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - discriminator_loss: -8.8274 - generator_loss: -4.5116[Log] Similarity metrics at epoch 4642 -> PSD_L2: 0.0000, MMD: 0.6736, KS_p: 0.0092
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4643.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4643.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4643
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4643.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - discriminator_loss: -8.8201 - generator_loss: -4.5056 - val_discriminator_loss: -6.7823 - val_generator_loss: -1.0863
# Epoch 4644/5000
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 4641 that is less than the current step 4642. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -5.7717 - generator_loss: -1.8589[Log] Similarity metrics at epoch 4643 -> PSD_L2: 0.0000, MMD: 0.6736, KS_p: 0.0002
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4644.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4644.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4644
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4644.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - discriminator_loss: -5.7689 - generator_loss: -1.8556 - val_discriminator_loss: -5.0960 - val_generator_loss: 2.0752
# Epoch 4645/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - discriminator_loss: -4.4814 - generator_loss: -0.6111[Log] Similarity metrics at epoch 4644 -> PSD_L2: 0.0000, MMD: 0.6736, KS_p: 0.0023
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4645.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4645.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4645
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4645.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - discriminator_loss: -4.4790 - generator_loss: -0.6288 - val_discriminator_loss: -4.1390 - val_generator_loss: -10.6465
# Epoch 4646/5000
# 134/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -4.3045 - generator_loss: -16.6985[Log] Similarity metrics at epoch 4645 -> PSD_L2: 0.0000, MMD: 0.6735, KS_p: 0.0020
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4646.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4646.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4646
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4646.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - discriminator_loss: -4.3099 - generator_loss: -16.5350 - val_discriminator_loss: -4.8567 - val_generator_loss: -7.1304
# Epoch 4647/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -4.8731 - generator_loss: -8.3022[Log] Similarity metrics at epoch 4646 -> PSD_L2: 0.0000, MMD: 0.6739, KS_p: 0.0002
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4647.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4647.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4647
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4647.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - discriminator_loss: -4.8726 - generator_loss: -8.2966 - val_discriminator_loss: -5.0674 - val_generator_loss: -2.6146
# Epoch 4648/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -4.8517 - generator_loss: -1.5373[Log] Similarity metrics at epoch 4647 -> PSD_L2: 0.0000, MMD: 0.6733, KS_p: 0.0003
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4648.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4648.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4648
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4648.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - discriminator_loss: -4.8511 - generator_loss: -1.5474 - val_discriminator_loss: -4.7912 - val_generator_loss: -14.5272
# Epoch 4649/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -4.6655 - generator_loss: -17.5780[Log] Similarity metrics at epoch 4648 -> PSD_L2: 0.0000, MMD: 0.6763, KS_p: 0.0000
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4649.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4649.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4649
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4649.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - discriminator_loss: -4.6644 - generator_loss: -17.6016 - val_discriminator_loss: -4.6137 - val_generator_loss: -28.8077
# Epoch 4650/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -4.5441 - generator_loss: -38.1510[Log] Similarity metrics at epoch 4649 -> PSD_L2: 0.0000, MMD: 0.6737, KS_p: 0.0014
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4650.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4650.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4650
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4650.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step
━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - discriminator_loss: -3.6930 - generator_loss: 10.2502[Log] Similarity metrics at epoch 4659 -> PSD_L2: 0.0000, MMD: 0.8390, KS_p: 0.0000
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4660.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4660.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4660
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4660.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - discriminator_loss: -3.6913 - generator_loss: 10.2291 - val_discriminator_loss: -3.7310 - val_generator_loss: 5.7648
# Epoch 4661/5000
# 134/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -3.6198 - generator_loss: 9.8893[Log] Similarity metrics at epoch 4660 -> PSD_L2: 0.0000, MMD: 0.7480, KS_p: 0.0010
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4661.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4661.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4661
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4661.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - discriminator_loss: -3.6180 - generator_loss: 9.9486 - val_discriminator_loss: -3.4362 - val_generator_loss: 13.0592
# Epoch 4662/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -3.5538 - generator_loss: 13.8480[Log] Similarity metrics at epoch 4661 -> PSD_L2: 0.0000, MMD: 0.6805, KS_p: 0.0034
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4662.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4662.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4662
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4662.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - discriminator_loss: -3.5525 - generator_loss: 13.8753 - val_discriminator_loss: -3.3774 - val_generator_loss: 16.4500
# Epoch 4663/5000
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -3.5040 - generator_loss: 17.4264[Log] Similarity metrics at epoch 4662 -> PSD_L2: 0.0000, MMD: 0.6596, KS_p: 0.0006
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4663.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4663.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4663
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4663.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - discriminator_loss: -3.5035 - generator_loss: 17.4342 - val_discriminator_loss: -3.2929 - val_generator_loss: 19.6824
# Epoch 4664/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -3.3969 - generator_loss: 20.8466[Log] Similarity metrics at epoch 4663 -> PSD_L2: 0.0000, MMD: 0.8048, KS_p: 0.0021
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4664.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4664.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4664
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4664.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - discriminator_loss: -3.3959 - generator_loss: 20.8715 - val_discriminator_loss: -3.2242 - val_generator_loss: 20.3246
# Epoch 4665/5000
# 134/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -3.3671 - generator_loss: 20.7771[Log] Similarity metrics at epoch 4664 -> PSD_L2: 0.0000, MMD: 0.6829, KS_p: 0.0011
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4665.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4665.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4665
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4665.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - discriminator_loss: -3.3650 - generator_loss: 20.7887 - val_discriminator_loss: -3.0939 - val_generator_loss: 19.5371
# Epoch 4666/5000
# 134/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -3.2846 - generator_loss: 21.6858[Log] Similarity metrics at epoch 4665 -> PSD_L2: 0.0000, MMD: 0.6573, KS_p: 0.0022
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4666.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4666.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4666
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4666.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - discriminator_loss: -3.2827 - generator_loss: 21.7104 - val_discriminator_loss: -3.0406 - val_generator_loss: 22.3143
# Epoch 4667/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -3.2065 - generator_loss: 22.8370[Log] Similarity metrics at epoch 4666 -> PSD_L2: 0.0000, MMD: 0.6519, KS_p: 0.0043
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4667.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4667.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4667
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4667.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - discriminator_loss: -3.2058 - generator_loss: 22.8445 - val_discriminator_loss: -2.9499 - val_generator_loss: 23.8562
# Epoch 4668/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -3.1725 - generator_loss: 21.8921[Log] Similarity metrics at epoch 4667 -> PSD_L2: 0.0000, MMD: 0.6511, KS_p: 0.0021
# ...
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4987
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4987.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - discriminator_loss: -2.3781 - generator_loss: 26.7375 - val_discriminator_loss: -1.5028 - val_generator_loss: 21.8389
# Epoch 4988/5000
# 134/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss:
5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -2.3611 - generator_loss: 28.0916[Log] Similarity metrics at epoch 4996 -> PSD_L2: 0.0000, MMD: 0.6550, KS_p: 0.0067
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4997.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4997.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4997
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4997.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - discriminator_loss: -2.3607 - generator_loss: 28.0991 - val_discriminator_loss: -1.5697 - val_generator_loss: 23.5155
# Epoch 4998/5000
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -2.3147 - generator_loss: 28.4396[Log] Similarity metrics at epoch 4997 -> PSD_L2: 0.0000, MMD: 0.6613, KS_p: 0.0426
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4998.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4998.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4998
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4998.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - discriminator_loss: -2.3148 - generator_loss: 28.4450 - val_discriminator_loss: -1.5284 - val_generator_loss: 26.0408
# Epoch 4999/5000
# 134/137 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - discriminator_loss: -2.2999 - generator_loss: 28.5553[Log] Similarity metrics at epoch 4998 -> PSD_L2: 0.0000, MMD: 0.7606, KS_p: 0.0024
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4999.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-4999.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-4999
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-4999.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - discriminator_loss: -2.3003 - generator_loss: 28.5515 - val_discriminator_loss: -1.5288 - val_generator_loss: 24.5884
# Epoch 5000/5000
# 135/137 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - discriminator_loss: -2.3845 - generator_loss: 28.5833[Log] Similarity metrics at epoch 4999 -> PSD_L2: 0.0000, MMD: 0.6430, KS_p: 0.0293
# [Saved] Model weights saved to: ./checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-5000.weights.h5
# [Backup] Model weights saved to: ./checkpoints/original/model-ltuwf57w/backup-epoch-5000.weights.h5
# [Resume] Model weights saved to: /content/drive/MyDrive/cs231n/student-radar/paper/wandb/run-20250605_074256-ltuwf57w/files/model-ltuwf57w.weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [Saved] Generator model saved to: ./checkpoints/original/model-ltuwf57w/generator-epoch-5000
# [Cleanup] Deleted old backup: ./checkpoints/original/model-ltuwf57w/backup-epoch-5000.weights.h5
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - discriminator_loss: -2.3844 - generator_loss: 28.5907 - val_discriminator_loss: -1.5198 - val_generator_loss: 24.2802
#
# [INFO] Total training time: 2255.94 seconds

# %%
# !python src/generate/save_conditional_generations.py --output_name test_6000_generations --num_generations 6000 --model_type original
# Out:
# 2025-06-04 00:39:53.389684: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-04 00:39:53.407559: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748997593.428488   16412 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748997593.434866   16412 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-04 00:39:53.455838: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-06-04 00:39:57.275223: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-04 00:39:57.275264: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: be285182961f
# 2025-06-04 00:39:57.275276: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: be285182961f
# 2025-06-04 00:39:57.275405: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 550.54.15
# 2025-06-04 00:39:57.275433: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 550.54.15
# 2025-06-04 00:39:57.275443: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 550.54.15
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [INFO] Generator and discriminator successfully built.
# [INFO] Using most recent model directory: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/original/model-bnmg4qg7
# [INFO] Using latest checkpoint: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/original/model-bnmg4qg7/model-bnmg4qg7-epoch-50.weights.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# [INFO] Loading weights from: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/original/model-bnmg4qg7/model-bnmg4qg7-epoch-50.weights.h5
# [INFO] Generated data shape: (6000, 16, 1024)
# Generation time: 2.05 seconds
# [Saved] /content/drive/MyDrive/cs231n/data/generated/original/model-bnmg4qg7/test_6000_generations.npy
