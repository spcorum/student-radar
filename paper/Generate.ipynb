# %%
# Mount Google Drive to access dataset
from google.colab import drive
drive.mount('/content/drive')
import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
print(tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# 2.18.0
# GPUs: []

# %%
# for Vimala and Sean
# %cd /content/drive/MyDrive/cs231n/student-radar/paper
# for Susan
# %cd /content/drive/MyDrive/student-radar/paper/
# !pwd
# !ls
# Out:
# /content/drive/MyDrive/cs231n/student-radar/paper
# /content/drive/MyDrive/cs231n/student-radar/paper
# analysis	  DoStudent2.ipynb	model-rqef7im3.h5  Test3.ipynb
# Analysis.ipynb	  DoStudent.ipynb	model-ryyt9way.h5  Test4.ipynb
# checkpoints	  generated_traces.png	README.md	   Test5.ipynb
# data		  Generate.ipynb	src		   Test.ipynb
# DoBoth.ipynb	  loss_plot.png		summary.png	   wandb
# DoOriginal.ipynb  model-gi5l7fcx.h5	summary.svg

# %%
# !python src/generate/save_conditional_generations.py --output_name generations_10000 --num_generations 10000 --model_type student --model 9idubkqi
# Out:
# 2025-06-05 05:33:11.879898: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749101591.895855   33645 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749101591.899956   33645 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-05 05:33:15.338512: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# [INFO] Generator and discriminator successfully built.
# [INFO] Using latest checkpoint: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-2632.weights.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 50 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# [INFO] Loading weights from: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/student/model-9idubkqi/model-9idubkqi-epoch-2632.weights.h5
# [INFO] Generated data shape: (10000, 16, 1024)
# Generation time: 9.65 seconds
# [Output directory] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/student/model-9idubkqi/generations_10000
# [Output generations file] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/student/model-9idubkqi/generations_10000/generator_data.npy
# [Output labels file] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/student/model-9idubkqi/generations_10000/generator_data.npy
# [Saved] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/student/model-9idubkqi/generations_10000/generator_data.npy
# [Saved] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/student/model-9idubkqi/generations_10000/generator_labels.npy

# %%
#!python src/generate/save_conditional_generations.py --output_name generations_10000 --num_generations 10000 --model_type student --model h1k2x95j
# Out:
# 2025-06-04 23:19:32.136377: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749079172.150282    6099 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749079172.154266    6099 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-04 23:19:35.612617: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# [INFO] Generator and discriminator successfully built.
# [INFO] Using latest checkpoint: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-1135.weights.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 50 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# [INFO] Loading weights from: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/student/model-h1k2x95j/model-h1k2x95j-epoch-1135.weights.h5
# [INFO] Generated data shape: (10000, 16, 1024)
# Generation time: 9.62 seconds
# [Output directory] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/student/model-h1k2x95j/generations_10000
# [Output generations file] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/student/model-h1k2x95j/generations_10000/generator_data.npy
# [Output labels file] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/student/model-h1k2x95j/generations_10000/generator_data.npy
# [Saved] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/student/model-h1k2x95j/generations_10000/generator_data.npy
# [Saved] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/student/model-h1k2x95j/generations_10000/generator_labels.npy

# %%
# !python src/generate/save_conditional_generations.py --output_name generations_10000 --num_generations 10000 --model_type original --model rghsxmf6
# Out:
# 2025-06-05 03:52:23.031802: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749095543.045345    9214 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749095543.049229    9214 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-06-05 03:52:40.192431: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [INFO] Generator and discriminator successfully built.
# [INFO] Using latest checkpoint: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/original/model-rghsxmf6/model-rghsxmf6-epoch-4610.weights.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# [INFO] Loading weights from: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/original/model-rghsxmf6/model-rghsxmf6-epoch-4610.weights.h5
# [INFO] Generated data shape: (10000, 16, 1024)
# Generation time: 8.84 seconds
# [Output directory] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/original/model-rghsxmf6/generations_10000
# [Output generations file] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/original/model-rghsxmf6/generations_10000/generator_data.npy
# [Output labels file] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/original/model-rghsxmf6/generations_10000/generator_data.npy
# [Saved] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/original/model-rghsxmf6/generations_10000/generator_data.npy
# [Saved] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/original/model-rghsxmf6/generations_10000/generator_labels.npy

# %%
# !python src/generate/save_conditional_generations.py --output_name generations_10000 --num_generations 10000 --model_type original --model ltuwf57w
# Out:
# 2025-06-04 23:21:03.326930: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749079263.341202    6607 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749079263.345232    6607 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-06-04 23:21:06.724970: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [INFO] Generator and discriminator successfully built.
# [INFO] Using latest checkpoint: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4640.weights.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# [INFO] Loading weights from: /content/drive/MyDrive/cs231n/student-radar/paper/checkpoints/original/model-ltuwf57w/model-ltuwf57w-epoch-4640.weights.h5
# [INFO] Generated data shape: (10000, 16, 1024)
# Generation time: 8.38 seconds
# [Output directory] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/original/model-ltuwf57w/generations_10000
# [Output generations file] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/original/model-ltuwf57w/generations_10000/generator_data.npy
# [Output labels file] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/original/model-ltuwf57w/generations_10000/generator_data.npy
# [Saved] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/original/model-ltuwf57w/generations_10000/generator_data.npy
# [Saved] /content/drive/MyDrive/cs231n/student-radar/paper/data/generated/original/model-ltuwf57w/generations_10000/generator_labels.npy
